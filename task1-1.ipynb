# %%
import pandas as pd

# %%
data = pd.read_csv('Demographic_Data.csv')

# %%
data.head()
# Out:
#    in-store  age  items   amount  region
# 0         0   37      4   281.03       2
# 1         0   35      2   219.51       2
# 2         1   45      3  1525.70       4
# 3         1   46      3   715.25       3
# 4         1   33      4  1937.50       1

# %%
data.describe()
# Out:
#            in-store           age         items        amount        region
# count  80000.000000  80000.000000  80000.000000  80000.000000  80000.000000
# mean       0.500000     45.757925      4.504975    835.919670      2.675000
# std        0.500003     15.715679      2.061238    721.273736      1.126672
# min        0.000000     18.000000      1.000000      5.004700      1.000000
# 25%        0.000000     33.000000      3.000000    285.140000      2.000000
# 50%        0.500000     45.000000      4.000000    582.315000      3.000000
# 75%        1.000000     56.000000      6.000000   1233.700000      4.000000
# max        1.000000     85.000000      8.000000   3000.000000      4.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80000 entries, 0 to 79999
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   in-store  80000 non-null  int64
#  1   age       80000 non-null  int64
#  2   items     80000 non-null  int64
#  3   amount    80000 non-null  float64
#  4   region    80000 non-null  int64
# dtypes: float64(1), int64(4)
# memory usage: 3.1 MB

# %%
data = data.drop_duplicates()

# %%
print(data.isnull().sum())
# Out:
# in-store    0
# age         0
# items       0
# amount      0
# region      0
# dtype: int64

# %%
data.dtypes
# Out:
# in-store      int64
# age           int64
# items         int64
# amount      float64
# region        int64
# dtype: object

# %%
import matplotlib.pyplot as plt

# %%
header = data.dtypes.index
print(header)
# Out:
# Index(['in-store', 'age', 'items', 'amount', 'region'], dtype='object')

# %%
plt.hist(data['in-store'])
plt.show()

# %%
plt.hist(data['in-store'], bins=4)
# Out:
# (array([39989.,     0.,     0., 39990.]),
#  array([0.  , 0.25, 0.5 , 0.75, 1.  ]),
#  <BarContainer object of 4 artists>)

# %%
import numpy as np

# %%
# Data for plotting
t = np.arange(0.0, 2.0, 0.01)
s = 1 + np.sin(2 * np.pi * t)

# %%
fig, ax = plt.subplots()
ax.plot(t, s)
plt.show()

# %%
data_sample = data.sample(100)

# %%
x = data_sample['items']
y = data_sample['amount']
plt.scatter(x,y, marker='o')
plt.show()

# %%
x = data_sample['region']
y = data_sample['amount']
plt.scatter(x,y, marker='o')
plt.show()

# %%
x = data_sample['age']
y = data_sample['amount']

# %%
plt.scatter(x,y, marker='o')
plt.show()

# %%
npArr1 = np.array(data['amount'])
npArr2 = np.array(data['items'])
npArr3 = np.array(data['region'])

# %%
np.corrcoef(npArr1, npArr2)
# Out:
# array([[1.00000000e+00, 3.83930433e-04],
#        [3.83930433e-04, 1.00000000e+00]])

# %%
np.corrcoef(npArr1, npArr3)
# Out:
# array([[1.        , 0.40348584],
#        [0.40348584, 1.        ]])

# %%
data.corr()
# Out:
#           in-store       age     items    amount    region
# in-store  1.000000 -0.178180 -0.003897 -0.085573 -0.133171
# age      -0.178180  1.000000  0.000657 -0.282033 -0.235370
# items    -0.003897  0.000657  1.000000  0.000384 -0.001904
# amount   -0.085573 -0.282033  0.000384  1.000000  0.403486
# region   -0.133171 -0.235370 -0.001904  0.403486  1.000000

# %%
from scipy import stats

# %%
from scipy.stats import pearsonr

# %%
from scipy.stats import spearmanr

# %%
pearsonr(data['amount'], data['items'])
# Out:
# (0.00038393043328058913, 0.9135388142059448)

# %%
pearsonr(data['amount'], data['region'])
# Out:
# (0.40348584249876274, 0.0)

# %%
import seaborn as sns

# %%
sns.pairplot(data)

# %%
dude = data[['amount','items','region']]
sns.pairplot(dude)

# %%
dude = data[['amount','items']]
sns.pairplot(dude)

# %%
region = data['region']
amount = data['amount']
items = data['items']

spearman_coefficient, p_value = spearmanr(amount, items)
print(spearman_coefficient)
# Out:
# -0.00037965687171861924

# %%
spearman_coefficient, p_value = spearmanr(amount, region)
print(spearman_coefficient)
# Out:
# 0.40178627080273177

# %%
from scipy.stats import chi

# %%
data.corr()
# Out:
#           in-store       age     items    amount    region
# in-store  1.000000 -0.178180 -0.003897 -0.085573 -0.133171
# age      -0.178180  1.000000  0.000657 -0.282033 -0.235370
# items    -0.003897  0.000657  1.000000  0.000384 -0.001904
# amount   -0.085573 -0.282033  0.000384  1.000000  0.403486
# region   -0.133171 -0.235370 -0.001904  0.403486  1.000000

# %%
x = data_sample['amount']
y = data_sample['items']

plt.scatter(x,y)

# %%
print(cov_mat)
# Out:
#            in-store          age     items         amount      region
# in-store   0.250003    -1.400071 -0.004017     -30.860425   -0.075019
# age       -1.400071   246.966189  0.021270   -3196.782841   -4.167305
# items     -0.004017     0.021270  4.248751       0.570791   -0.004421
# amount   -30.860425 -3196.782841  0.570791  520221.252295  327.874873
# region    -0.075019    -4.167305 -0.004421     327.874873    1.269321

# %%
print(header)
# Out:
# Index(['in-store', 'age', 'items', 'amount', 'region'], dtype='object')

# %%
A = data['amount']
plt.boxplot(A,0,'gD')
plt.show()

# %%
A = data['region']
plt.boxplot(A,0,'gD')
plt.show()

# %%
A = data['items']
plt.boxplot(A,0,'gD')
plt.show()

# %%
A = data['age']
plt.boxplot(A,0,'gD')
plt.show()

# %%
data.corr()
# Out:
#           in-store       age     items    amount    region
# in-store  1.000000 -0.178180 -0.003897 -0.085573 -0.133171
# age      -0.178180  1.000000  0.000657 -0.282033 -0.235370
# items    -0.003897  0.000657  1.000000  0.000384 -0.001904
# amount   -0.085573 -0.282033  0.000384  1.000000  0.403486
# region   -0.133171 -0.235370 -0.001904  0.403486  1.000000

# %%
cov_mat = data.cov()
print(cov_mat)
# Out:
#            in-store          age     items         amount      region
# in-store   0.250003    -1.400071 -0.004017     -30.860425   -0.075019
# age       -1.400071   246.966189  0.021270   -3196.782841   -4.167305
# items     -0.004017     0.021270  4.248751       0.570791   -0.004421
# amount   -30.860425 -3196.782841  0.570791  520221.252295  327.874873
# region    -0.075019    -4.167305 -0.004421     327.874873    1.269321

# %%
print(header)
# Out:
# Index(['in-store', 'age', 'items', 'amount', 'region'], dtype='object')

# %%
print(corr_mat)
# Out:
#           in-store       age     items    amount    region
# in-store  1.000000 -0.178180 -0.003897 -0.085573 -0.133171
# age      -0.178180  1.000000  0.000657 -0.282033 -0.235370
# items    -0.003897  0.000657  1.000000  0.000384 -0.001904
# amount   -0.085573 -0.282033  0.000384  1.000000  0.403486
# region   -0.133171 -0.235370 -0.001904  0.403486  1.000000

# %%
data.head()
# Out:
#    in-store  age  items   amount  region
# 0         0   37      4   281.03       2
# 1         0   35      2   219.51       2
# 2         1   45      3  1525.70       4
# 3         1   46      3   715.25       3
# 4         1   33      4  1937.50       1

# %%
data.columns
# Out:
# Index(['in-store', 'age', 'items', 'amount', 'region'], dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79979 entries, 0 to 79999
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   in-store  79979 non-null  int64
#  1   age       79979 non-null  int64
#  2   items     79979 non-null  int64
#  3   amount    79979 non-null  float64
#  4   region    79979 non-null  int64
# dtypes: float64(1), int64(4)
# memory usage: 3.7 MB

# %%
data.groupby('region') ['region'].count()
# Out:
# region
# 1    15997
# 2    19994
# 3    18000
# 4    25988
# Name: region, dtype: int64

# %%
data.groupby('in-store') ['in-store'].count ()
# Out:
# in-store
# 0    39989
# 1    39990
# Name: in-store, dtype: int64

# %%
data.groupby('items') ['items'].count()
# Out:
# items
# 1     5699
# 2    11284
# 3    11486
# 4    11594
# 5    11233
# 6    11519
# 7    11376
# 8     5788
# Name: items, dtype: int64

# %%
data.groupby('age') ['age'].count()
# Out:
# age
# 18     223
# 19     743
# 20    1009
# 21     937
# 22     975
#       ...
# 81     371
# 82     385
# 83     380
# 84     373
# 85     185
# Name: age, Length: 68, dtype: int64

# %%
import seaborn as sns

# %%
fg = sns.catplot('region', data=data, kind='count', aspect=1.5)
fg.set_xlabels('region')
# Out:
# C:\Users\bling\anaconda3\envs\task1.1\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fg = sns.catplot('items', data=data, kind='count', aspect=1.5)
fg.set_xlabels('items')
# Out:
# C:\Users\bling\anaconda3\envs\task1.1\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fg = sns.catplot('age', data=data, kind='count', aspect=1.5)
fg.set_xlabels('age')
# Out:
# C:\Users\bling\anaconda3\envs\task1.1\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79979 entries, 0 to 79999
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   in-store  79979 non-null  int64
#  1   age       79979 non-null  int64
#  2   items     79979 non-null  int64
#  3   amount    79979 non-null  float64
#  4   region    79979 non-null  int64
# dtypes: float64(1), int64(4)
# memory usage: 3.7 MB

# %%
data.groupby(['age', 'items'])['age'].count()
# Out:
# age  items
# 18   1        15
#      2        26
#      3        17
#      4        36
#      5        32
#               ..
# 85   4        31
#      5        22
#      6        23
#      7        29
#      8        11
# Name: age, Length: 544, dtype: int64

# %%
data.groupby(['in-store', 'age'])['age'].count()
# Out:
# in-store  age
# 0         18     223
#           19     454
#           20     461
#           21     378
#           22     453
#                 ...
# 1         70     423
#           71     379
#           72     382
#           73     366
#           74     221
# Name: age, Length: 124, dtype: int64

# %%
data.groupby(['region', 'items'])['region'].count()
# Out:
# region  items
# 1       1        1106
#         2        2221
#         3        2316
#         4        2390
#         5        2240
#         6        2358
#         7        2181
#         8        1185
# 2       1        1442
#         2        2828
#         3        2801
#         4        2891
#         5        2802
#         6        2890
#         7        2906
#         8        1434
# 3       1        1260
#         2        2576
#         3        2599
#         4        2675
#         5        2513
#         6        2515
#         7        2568
#         8        1294
# 4       1        1891
#         2        3659
#         3        3770
#         4        3638
#         5        3678
#         6        3756
#         7        3721
#         8        1875
# Name: region, dtype: int64

# %%
data.groupby(['region', 'amount'])['region'].count()
# Out:
# region  amount
# 1       50.050      1
#         50.294      1
#         50.372      1
#         50.547      1
#         50.627      1
#                    ..
# 4       2998.600    3
#         2999.000    1
#         2999.600    2
#         2999.700    1
#         3000.000    1
# Name: region, Length: 68517, dtype: int64

# %%
data.groupby(['amount', 'items'])['items'].count()
# Out:
# amount     items
# 5.0047     6        1
# 5.0604     2        1
# 5.0660     3        1
# 5.1175     6        1
# 5.1583     6        1
#                    ..
# 2999.6000  6        1
# 2999.7000  3        1
# 2999.8000  5        1
# 3000.0000  7        1
#            8        1
# Name: items, Length: 75772, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79979 entries, 0 to 79999
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   in-store  79979 non-null  int64
#  1   age       79979 non-null  int64
#  2   items     79979 non-null  int64
#  3   amount    79979 non-null  float64
#  4   region    79979 non-null  int64
# dtypes: float64(1), int64(4)
# memory usage: 3.7 MB

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79979 entries, 0 to 79999
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   in-store  79979 non-null  int64
#  1   age       79979 non-null  int64
#  2   items     79979 non-null  int64
#  3   amount    79979 non-null  float64
#  4   region    79979 non-null  int64
# dtypes: float64(1), int64(4)
# memory usage: 3.7 MB

# %% [raw]
# g = sns.catplot('region', data = data, hue='amount', kind='count', aspect=1.75)
# g.set_xlabels('Region')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79979 entries, 0 to 79999
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   in-store  79979 non-null  int64
#  1   age       79979 non-null  int64
#  2   items     79979 non-null  int64
#  3   amount    79979 non-null  float64
#  4   region    79979 non-null  int64
# dtypes: float64(1), int64(4)
# memory usage: 3.7 MB

# %%
fg = sns.catplot('in-store', data=data, kind='count', aspect=1.5)
fg.set_xlabels('In-Store')
# Out:
# C:\Users\bling\anaconda3\envs\task1.1\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79979 entries, 0 to 79999
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   in-store  79979 non-null  int64
#  1   age       79979 non-null  int64
#  2   items     79979 non-null  int64
#  3   amount    79979 non-null  float64
#  4   region    79979 non-null  int64
# dtypes: float64(1), int64(4)
# memory usage: 3.7 MB

# %%
g = sns.catplot('items', data=data, hue='region', kind='count', aspect=1.75)
g.set_xlabels('items')
# Out:
# C:\Users\bling\anaconda3\envs\task1.1\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.catplot(x="items", y="amount", hue="region", kind="bar", data=data)

# %%
data.pivot_table('amount', 'items' , 'region', aggfunc=np.sum, margins=True)
# Out:
# region             1             2             3             4           All
# items
# 1       8.311041e+05  3.714415e+05  1.126742e+06  2.374677e+06  4.703965e+06
# 2       1.703340e+06  7.070343e+05  2.400234e+06  4.746452e+06  9.557061e+06
# 3       1.722666e+06  7.063618e+05  2.381780e+06  4.798311e+06  9.609120e+06
# 4       1.738248e+06  7.216710e+05  2.501152e+06  4.657539e+06  9.618610e+06
# 5       1.670453e+06  7.072225e+05  2.290797e+06  4.699555e+06  9.368027e+06
# 6       1.744998e+06  7.368373e+05  2.271135e+06  4.869226e+06  9.622197e+06
# 7       1.609124e+06  7.315420e+05  2.337951e+06  4.763767e+06  9.442385e+06
# 8       8.976860e+05  3.583318e+05  1.213662e+06  2.457463e+06  4.927143e+06
# All     1.191762e+07  5.040442e+06  1.652345e+07  3.336699e+07  6.684851e+07

# %%
data.pivot_table('amount', 'items' , 'region', aggfunc=np.sum, margins=True)
# Out:
# region             1             2             3             4           All
# items
# 1       8.311041e+05  3.714415e+05  1.126742e+06  2.374677e+06  4.703965e+06
# 2       1.703340e+06  7.070343e+05  2.400234e+06  4.746452e+06  9.557061e+06
# 3       1.722666e+06  7.063618e+05  2.381780e+06  4.798311e+06  9.609120e+06
# 4       1.738248e+06  7.216710e+05  2.501152e+06  4.657539e+06  9.618610e+06
# 5       1.670453e+06  7.072225e+05  2.290797e+06  4.699555e+06  9.368027e+06
# 6       1.744998e+06  7.368373e+05  2.271135e+06  4.869226e+06  9.622197e+06
# 7       1.609124e+06  7.315420e+05  2.337951e+06  4.763767e+06  9.442385e+06
# 8       8.976860e+05  3.583318e+05  1.213662e+06  2.457463e+06  4.927143e+06
# All     1.191762e+07  5.040442e+06  1.652345e+07  3.336699e+07  6.684851e+07

# %%
data.pivot_table('amount', 'items' , 'region', aggfunc=np.average, margins=True)
# Out:
# region           1           2           3            4         All
# items
# 1       751.450329  257.587746  894.239667  1255.778428  825.401751
# 2       766.924871  250.012124  931.767999  1297.199268  846.956834
# 3       743.810869  252.182018  916.421853  1272.761661  836.594085
# 4       727.300536  249.626762  935.009959  1280.247027  829.619594
# 5       745.737906  252.399170  911.578511  1277.747343  833.973730
# 6       740.033224  254.961019  903.035816  1296.386021  835.332638
# 7       737.791975  251.735042  910.417209  1280.238420  830.026801
# 8       757.540969  249.882689  937.914856  1310.646915  851.268593
# All     744.990939  252.097741  917.969637  1283.938357  835.825727

# %%
data.amount.describe()
# Out:
# count    79979.000000
# mean       835.825727
# std        721.263650
# min          5.004700
# 25%        285.120000
# 50%        582.140000
# 75%       1233.400000
# max       3000.000000
# Name: amount, dtype: float64

# %%
data['amount'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
fig = sns.FacetGrid(data, hue='region', aspect=1.75)
fig.map(sns.kdeplot, 'amount', shade=True)
oldest = data['amount'].max()
fig.set(xlim=(0,oldest))
fig.set(title='Distribution of Amount by region')
fig.add_legend()

# %%
fig = sns.FacetGrid(data, hue='items', aspect=1.75)
fig.map(sns.kdeplot, 'amount', shade=False)
oldest = data['amount'].max()
fig.set(xlim=(0,oldest))
fig.set(title='Distrution of Items by Amount')
fig.add_legend()

# %%
sns.lmplot('amount', 'items', data=data)
# Out:
# C:\Users\bling\anaconda3\envs\task1.1\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.lmplot('amount', 'region', data=data)
# Out:
# C:\Users\bling\anaconda3\envs\task1.1\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.lmplot('age', 'amount', data)
# Out:
# C:\Users\bling\anaconda3\envs\task1.1\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
ax = sns.stripplot(x="items", y="amount", data=data)

# %%
ax = sns.stripplot(x="region", y="amount", data=data)

# %%
sns.set_theme(style="whitegrid")

# %%
ax = sns.stripplot(x="region", y="amount", data=data)

# %%
ax = sns.boxplot(x="items", y="amount", data=data, whis=np.inf)
ax = sns.stripplot(x="region", y="amount", data=data, color=".3")

# %%
g = sns.catplot(x="items", y="amount",
                hue="region", col="in-store",
                data=data, kind="strip")

# %%
sns.catplot(x="items", y="amount", hue="region", kind="violin", palette="pastel", data=data)

# %%
sns.catplot(x="region", y="amount", jitter=False, data=data)

# %%
sns.catplot(x="region", y="amount", jitter=True, data=data)

# %%
sns.catplot(x="items", y="amount", hue='region', jitter=False, data=data)

# %%
sns.catplot(x="items", y="amount", hue='region', palette="ch:.25", jitter=False, data=data)

# %%
import matplotlib as mpl

# %%
# !pip install plotly.express

# %%
import plotly.express as px

# %%
import plotly.figure_factory as ff

# %%
data.columns
# Out:
# Index(['in-store', 'age', 'items', 'amount', 'region'], dtype='object')

# %%
sns.lmplot('items', 'amount', data=data, hue='region')
# Out:
# C:\Users\bling\anaconda3\envs\task1.1\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.lmplot('region', 'amount', data, hue='items')
# Out:
# C:\Users\bling\anaconda3\envs\task1.1\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.lmplot('region', 'amount', hue='items', data=data, palette='winter')
# Out:
# C:\Users\bling\anaconda3\envs\task1.1\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
ax = sns.boxplot(x="items", y="amount", data=data, whis=np.inf)
ax = sns.stripplot(x="region", y="amount", data=data, color=".3")

# %%
data.region.value_counts()
# Out:
# 4    25988
# 2    19994
# 3    18000
# 1    15997
# Name: region, dtype: int64

# %%
Area = pd.crosstab(index=[data.region], columns=[data.region])

# %%
Area.columns = [['North','South','East','West']]

# %%
data.groupby('items') ['items'].count()
# Out:
# items
# 1     5699
# 2    11284
# 3    11486
# 4    11594
# 5    11233
# 6    11519
# 7    11376
# 8     5788
# Name: items, dtype: int64

# %%
Area.index
# Out:
# Int64Index([1, 2, 3, 4], dtype='int64', name='region')

# %%
Area.columns
# Out:
# MultiIndex([('North',),
#             ('South',),
#             ( 'East',),
#             ( 'West',)],
#            )

# %%
sns.catplot('items','amount', hue='region', data=data)
# Out:
# C:\Users\bling\anaconda3\envs\task1.1\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.catplot('region','amount', hue='items', data=data)
# Out:
# C:\Users\bling\anaconda3\envs\task1.1\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data.groupby(['amount', 'region'])['amount'].count()
# Out:
# amount     region
# 5.0047     2         1
# 5.0604     2         1
# 5.0660     2         1
# 5.1175     2         1
# 5.1583     2         1
#                     ..
# 2999.6000  4         2
# 2999.7000  4         1
# 2999.8000  3         1
# 3000.0000  3         1
#            4         1
# Name: amount, Length: 68517, dtype: int64

# %%
data.pivot_table('amount', 'items','region', aggfunc=np.sum, margins=True)
# Out:
# region             1             2             3             4           All
# items
# 1       8.311041e+05  3.714415e+05  1.126742e+06  2.374677e+06  4.703965e+06
# 2       1.703340e+06  7.070343e+05  2.400234e+06  4.746452e+06  9.557061e+06
# 3       1.722666e+06  7.063618e+05  2.381780e+06  4.798311e+06  9.609120e+06
# 4       1.738248e+06  7.216710e+05  2.501152e+06  4.657539e+06  9.618610e+06
# 5       1.670453e+06  7.072225e+05  2.290797e+06  4.699555e+06  9.368027e+06
# 6       1.744998e+06  7.368373e+05  2.271135e+06  4.869226e+06  9.622197e+06
# 7       1.609124e+06  7.315420e+05  2.337951e+06  4.763767e+06  9.442385e+06
# 8       8.976860e+05  3.583318e+05  1.213662e+06  2.457463e+06  4.927143e+06
# All     1.191762e+07  5.040442e+06  1.652345e+07  3.336699e+07  6.684851e+07

# %%
fig = sns.FacetGrid(data, hue='items', aspect=1.75)
fig.map(sns.kdeplot, 'amount', shade=True)
oldest = data['amount'].max()
fig.set(xlim=(0,oldest))
fig.set(title='Distribution of Amount by items')
fig.add_legend()

# %%
sns.catplot('in-store', data=data, kind='count')
# Out:
# C:\Users\bling\anaconda3\envs\task1.1\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
on_line = data[data['in-store']==0]

# %%
len(on_line)
# Out:
# 39989

# %%
on_line.pivot_table('in-store', 'items', 'region', aggfunc=len, margins=True)
# Out:
# region      2     3      4    All
# items
# 1        1442   473    925   2840
# 2        2828  1023   1828   5679
# 3        2801  1016   1870   5687
# 4        2891  1045   1838   5774
# 5        2802   950   1813   5565
# 6        2890   964   1867   5721
# 7        2906  1006   1901   5813
# 8        1434   524    952   2910
# All     19994  7001  12994  39989

# %%
on_line.pivot_table('in-store', 'items', 'region', aggfunc=len, margins=False)
# Out:
# region     2     3     4
# items
# 1       1442   473   925
# 2       2828  1023  1828
# 3       2801  1016  1870
# 4       2891  1045  1838
# 5       2802   950  1813
# 6       2890   964  1867
# 7       2906  1006  1901
# 8       1434   524   952

# %%
data.groupby('region')['region'].count()
# Out:
# region
# 1    15997
# 2    19994
# 3    18000
# 4    25988
# Name: region, dtype: int64

# %%
data.amount.describe()
# Out:
# count    79979.000000
# mean       835.825727
# std        721.263650
# min          5.004700
# 25%        285.120000
# 50%        582.140000
# 75%       1233.400000
# max       3000.000000
# Name: amount, dtype: float64

# %%
amount = data['amount'].dropna()

# %%
amount_dist = sns.distplot(amount)
amount_dist.set_title("Test Amount")
# Out:
# C:\Users\bling\anaconda3\envs\task1.1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Test Amount')

# %%
data['amount'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
data[:10]
# Out:
#    in-store  age  items     amount  region
# 0         0   37      4   281.0300       2
# 1         0   35      2   219.5100       2
# 2         1   45      3  1525.7000       4
# 3         1   46      3   715.2500       3
# 4         1   33      4  1937.5000       1
# 5         0   24      3  1314.2000       4
# 6         0   43      6     8.5472       2
# 7         1   66      5   819.9800       3
# 8         1   51      5   908.3100       1
# 9         1   47      3   767.5400       1

# %%
sns.catplot('items', data=data, kind='count', hue='region', col='in-store')
# Out:
# C:\Users\bling\anaconda3\envs\task1.1\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fg = sns.catplot('in-store', data=data, kind='count', aspect=1.5)
fg.set_xlabels('In-Store')
# Out:
# C:\Users\bling\anaconda3\envs\task1.1\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fig = sns.FacetGrid(data, hue='region', aspect=4)
fig.map(sns.kdeplot, 'amount', shade=True)
oldest = data['amount'].max()
fig.set(xlim=(0,oldest))
fig.set(title='Dist of Amount by region')
fig.add_legend()

# %%
fig = sns.FacetGrid(data, hue='region', aspect=2)
fig.map(sns.kdeplot, 'items', shade=False)
oldest = data['items'].max()
fig.set(xlim=(0,oldest))
fig.set(title='items by region')
fig.add_legend()

# %%
sns.catplot('items', data=data, kind='count', hue='region', aspect=2)
# Out:
# C:\Users\bling\anaconda3\envs\task1.1\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
region = data['region']
region.head()
# Out:
# 0    2
# 1    2
# 2    4
# 3    3
# 4    1
# Name: region, dtype: int64

# %%
data.region.value_counts()
# Out:
# 4    25988
# 2    19994
# 3    18000
# 1    15997
# Name: region, dtype: int64

# %%
purchase = pd.crosstab(index=[data.amount], columns=[data.region])

# %%
purchase
# Out:
# region     1  2  3  4
# amount
# 5.0047     0  1  0  0
# 5.0604     0  1  0  0
# 5.0660     0  1  0  0
# 5.1175     0  1  0  0
# 5.1583     0  1  0  0
# ...       .. .. .. ..
# 2999.4000  0  0  1  0
# 2999.6000  0  0  0  2
# 2999.7000  0  0  0  1
# 2999.8000  0  0  1  0
# 3000.0000  0  0  1  1
#
# [56112 rows x 4 columns]

# %%
purchase.index
# Out:
# Float64Index([5.0047, 5.0604,  5.066, 5.1175, 5.1583, 5.1762,  5.213, 5.2282,
#               5.2493,  5.261,
#               ...
#               2998.5, 2998.6, 2998.9, 2999.0, 2999.2, 2999.4, 2999.6, 2999.7,
#               2999.8, 3000.0],
#              dtype='float64', name='amount', length=56112)

# %%
purchase.columns
# Out:
# Int64Index([1, 2, 3, 4], dtype='int64', name='region')

# %%
purchase.columns=[['North','South','East', 'West']]

# %%
purchase
# Out:
#           North South East West
# amount
# 5.0047        0     1    0    0
# 5.0604        0     1    0    0
# 5.0660        0     1    0    0
# 5.1175        0     1    0    0
# 5.1583        0     1    0    0
# ...         ...   ...  ...  ...
# 2999.4000     0     0    1    0
# 2999.6000     0     0    0    2
# 2999.7000     0     0    0    1
# 2999.8000     0     0    1    0
# 3000.0000     0     0    1    1
#
# [56112 rows x 4 columns]

# %%
fg=sns.catplot('in-store', 'amount', data=data, hue='items', col='region',
                 palette='Blues')
fg.set_xlabels('Region?')
# Out:
# C:\Users\bling\anaconda3\envs\task1.1\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fg=sns.catplot('items', 'amount', data=data, hue='in-store', col='region',
                 palette='Blues')
fg.set_xlabels('Amount Per items purchased by region')
# Out:
# C:\Users\bling\anaconda3\envs\task1.1\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
from sklearn.datasets import load_digits

# %%
print()
